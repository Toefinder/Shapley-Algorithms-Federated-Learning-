# %%
# install pysyft for federated learning
#!pip install syft[udacity]

# %%
## this is the module required for federated learning
#import syft as sy

# %%
# %tensorflow_version 1.x   #ensure that TF 1.x is used when TF 2.x becomes the default
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x   #ensure that TF 1.x is used when TF 2.x becomes the default`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import helper
import matplotlib.pyplot as plt
import numpy as np
import copy
import random

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))
                              ])
# Download and load the training data
trainset = datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
# Out:
# ...
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# ...
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# ...
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# ...
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# Processing...
# Done!

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_dir = "/content/gdrive/My Drive/NTU/cy1400/"
base_dir = root_dir + 'cy1400/'

# %%
import pickle
with open(base_dir + "dictionary1.out", "rb") as pickle_1:
  dictionary1 = pickle.load(pickle_1)
with open(base_dir + "dictionary2.out", "rb") as pickle_2:
  dictionary2 = pickle.load(pickle_2)
with open(base_dir + "dictionary3.out", "rb") as pickle_3:
  dictionary3 = pickle.load(pickle_3)
with open(base_dir + "dictionary4.out", "rb") as pickle_4:
  dictionary4 = pickle.load(pickle_4)
with open(base_dir + "dictionary5.out", "rb") as pickle_5:
  dictionary5 = pickle.load(pickle_5)

# %%
#powersets that we need to create
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
list(powerset("12345"))
# Out:
# [(),
#  ('1',),
#  ('2',),
#  ('3',),
#  ('4',),
#  ('5',),
#  ('1', '2'),
#  ('1', '3'),
#  ('1', '4'),
#  ('1', '5'),
#  ('2', '3'),
#  ('2', '4'),
#  ('2', '5'),
#  ('3', '4'),
#  ('3', '5'),
#  ('4', '5'),
#  ('1', '2', '3'),
#  ('1', '2', '4'),
#  ('1', '2', '5'),
#  ('1', '3', '4'),
#  ('1', '3', '5'),
#  ('1', '4', '5'),
#  ('2', '3', '4'),
#  ('2', '3', '5'),
#  ('2', '4', '5'),
#  ('3', '4', '5'),
#  ('1', '2', '3', '4'),
#  ('1', '2', '3', '5'),
#  ('1', '2', '4', '5'),
#  ('1', '3', '4', '5'),
#  ('2', '3', '4', '5'),
#  ('1', '2', '3', '4', '5')]

# %%
cdictionary1 = {}
cdictionary1['ctrainset_1_12'] = []
cdictionary1['ctrainset_1_13'] = []
cdictionary1['ctrainset_1_14'] = []
cdictionary1['ctrainset_1_15'] = []
cdictionary1['ctrainset_1_23'] = []
cdictionary1['ctrainset_1_24'] = []
cdictionary1['ctrainset_1_25'] = []
cdictionary1['ctrainset_1_34'] = []
cdictionary1['ctrainset_1_35'] = []
cdictionary1['ctrainset_1_45'] = []
cdictionary1['ctrainset_1_123'] = []
cdictionary1['ctrainset_1_124'] = []
cdictionary1['ctrainset_1_125'] = []
cdictionary1['ctrainset_1_134'] = []
cdictionary1['ctrainset_1_135'] = []
cdictionary1['ctrainset_1_145'] = []
cdictionary1['ctrainset_1_234'] = []
cdictionary1['ctrainset_1_235'] = []
cdictionary1['ctrainset_1_245'] = []
cdictionary1['ctrainset_1_345'] = []
cdictionary1['ctrainset_1_1234'] = []
cdictionary1['ctrainset_1_1235'] = []
cdictionary1['ctrainset_1_1245'] = []
cdictionary1['ctrainset_1_1345'] = []
cdictionary1['ctrainset_1_2345'] = []
cdictionary1['ctrainset_1_12345'] = []

# %%
cdictionary2 = {}
cdictionary2['ctrainset_2_12'] = []
cdictionary2['ctrainset_2_13'] = []
cdictionary2['ctrainset_2_14'] = []
cdictionary2['ctrainset_2_15'] = []
cdictionary2['ctrainset_2_23'] = []
cdictionary2['ctrainset_2_24'] = []
cdictionary2['ctrainset_2_25'] = []
cdictionary2['ctrainset_2_34'] = []
cdictionary2['ctrainset_2_35'] = []
cdictionary2['ctrainset_2_45'] = []
cdictionary2['ctrainset_2_123'] = []
cdictionary2['ctrainset_2_124'] = []
cdictionary2['ctrainset_2_125'] = []
cdictionary2['ctrainset_2_134'] = []
cdictionary2['ctrainset_2_135'] = []
cdictionary2['ctrainset_2_145'] = []
cdictionary2['ctrainset_2_234'] = []
cdictionary2['ctrainset_2_235'] = []
cdictionary2['ctrainset_2_245'] = []
cdictionary2['ctrainset_2_345'] = []
cdictionary2['ctrainset_2_1234'] = []
cdictionary2['ctrainset_2_1235'] = []
cdictionary2['ctrainset_2_1245'] = []
cdictionary2['ctrainset_2_1345'] = []
cdictionary2['ctrainset_2_2345'] = []
cdictionary2['ctrainset_2_12345'] = []

# %%
cdictionary3 = {}
cdictionary3['ctrainset_3_12'] = []
cdictionary3['ctrainset_3_13'] = []
cdictionary3['ctrainset_3_14'] = []
cdictionary3['ctrainset_3_15'] = []
cdictionary3['ctrainset_3_23'] = []
cdictionary3['ctrainset_3_24'] = []
cdictionary3['ctrainset_3_25'] = []
cdictionary3['ctrainset_3_34'] = []
cdictionary3['ctrainset_3_35'] = []
cdictionary3['ctrainset_3_45'] = []
cdictionary3['ctrainset_3_123'] = []
cdictionary3['ctrainset_3_124'] = []
cdictionary3['ctrainset_3_125'] = []
cdictionary3['ctrainset_3_134'] = []
cdictionary3['ctrainset_3_135'] = []
cdictionary3['ctrainset_3_145'] = []
cdictionary3['ctrainset_3_234'] = []
cdictionary3['ctrainset_3_235'] = []
cdictionary3['ctrainset_3_245'] = []
cdictionary3['ctrainset_3_345'] = []
cdictionary3['ctrainset_3_1234'] = []
cdictionary3['ctrainset_3_1235'] = []
cdictionary3['ctrainset_3_1245'] = []
cdictionary3['ctrainset_3_1345'] = []
cdictionary3['ctrainset_3_2345'] = []
cdictionary3['ctrainset_3_12345'] = []

# %%
cdictionary4 = {}
cdictionary4['ctrainset_4_12'] = []
cdictionary4['ctrainset_4_13'] = []
cdictionary4['ctrainset_4_14'] = []
cdictionary4['ctrainset_4_15'] = []
cdictionary4['ctrainset_4_23'] = []
cdictionary4['ctrainset_4_24'] = []
cdictionary4['ctrainset_4_25'] = []
cdictionary4['ctrainset_4_34'] = []
cdictionary4['ctrainset_4_35'] = []
cdictionary4['ctrainset_4_45'] = []
cdictionary4['ctrainset_4_123'] = []
cdictionary4['ctrainset_4_124'] = []
cdictionary4['ctrainset_4_125'] = []
cdictionary4['ctrainset_4_134'] = []
cdictionary4['ctrainset_4_135'] = []
cdictionary4['ctrainset_4_145'] = []
cdictionary4['ctrainset_4_234'] = []
cdictionary4['ctrainset_4_235'] = []
cdictionary4['ctrainset_4_245'] = []
cdictionary4['ctrainset_4_345'] = []
cdictionary4['ctrainset_4_1234'] = []
cdictionary4['ctrainset_4_1235'] = []
cdictionary4['ctrainset_4_1245'] = []
cdictionary4['ctrainset_4_1345'] = []
cdictionary4['ctrainset_4_2345'] = []
cdictionary4['ctrainset_4_12345'] = []

# %%
cdictionary5 = {}
cdictionary5['ctrainset_5_12'] = []
cdictionary5['ctrainset_5_13'] = []
cdictionary5['ctrainset_5_14'] = []
cdictionary5['ctrainset_5_15'] = []
cdictionary5['ctrainset_5_23'] = []
cdictionary5['ctrainset_5_24'] = []
cdictionary5['ctrainset_5_25'] = []
cdictionary5['ctrainset_5_34'] = []
cdictionary5['ctrainset_5_35'] = []
cdictionary5['ctrainset_5_45'] = []
cdictionary5['ctrainset_5_123'] = []
cdictionary5['ctrainset_5_124'] = []
cdictionary5['ctrainset_5_125'] = []
cdictionary5['ctrainset_5_134'] = []
cdictionary5['ctrainset_5_135'] = []
cdictionary5['ctrainset_5_145'] = []
cdictionary5['ctrainset_5_234'] = []
cdictionary5['ctrainset_5_235'] = []
cdictionary5['ctrainset_5_245'] = []
cdictionary5['ctrainset_5_345'] = []
cdictionary5['ctrainset_5_1234'] = []
cdictionary5['ctrainset_5_1235'] = []
cdictionary5['ctrainset_5_1245'] = []
cdictionary5['ctrainset_5_1345'] = []
cdictionary5['ctrainset_5_2345'] = []
cdictionary5['ctrainset_5_12345'] = []

# %%
#create cdictionary1
cdictionary1['ctrainset_1_12'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_12'].extend(dictionary1['trainset_1_2'])

cdictionary1['ctrainset_1_13'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_13'].extend(dictionary1['trainset_1_3'])

cdictionary1['ctrainset_1_14'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_14'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_15'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_15'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_23'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_23'].extend(dictionary1['trainset_1_3'])

cdictionary1['ctrainset_1_24'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_24'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_25'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_25'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_34'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_34'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_35'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_35'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_45'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_45'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_123'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_123'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_123'].extend(dictionary1['trainset_1_3'])

cdictionary1['ctrainset_1_124'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_124'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_124'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_125'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_125'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_125'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_134'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_134'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_134'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_135'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_135'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_135'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_145'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_145'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_145'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_234'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_234'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_234'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_235'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_235'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_235'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_245'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_245'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_245'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_345'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_345'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_345'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_1234'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_1234'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_1234'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_1234'].extend(dictionary1['trainset_1_4'])

cdictionary1['ctrainset_1_1235'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_1235'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_1235'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_1235'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_1245'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_1245'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_1245'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_1245'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_1345'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_1345'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_1345'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_1345'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_2345'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_2345'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_2345'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_2345'].extend(dictionary1['trainset_1_5'])

cdictionary1['ctrainset_1_12345'].extend(dictionary1['trainset_1_1'])
cdictionary1['ctrainset_1_12345'].extend(dictionary1['trainset_1_2'])
cdictionary1['ctrainset_1_12345'].extend(dictionary1['trainset_1_3'])
cdictionary1['ctrainset_1_12345'].extend(dictionary1['trainset_1_4'])
cdictionary1['ctrainset_1_12345'].extend(dictionary1['trainset_1_5'])

# %%
len(cdictionary1['ctrainset_1_145'])
# Out:
# 32520

# %%
#create cdictionary2
cdictionary2['ctrainset_2_12'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_12'].extend(dictionary2['trainset_2_2'])

cdictionary2['ctrainset_2_13'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_13'].extend(dictionary2['trainset_2_3'])

cdictionary2['ctrainset_2_14'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_14'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_15'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_15'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_23'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_23'].extend(dictionary2['trainset_2_3'])

cdictionary2['ctrainset_2_24'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_24'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_25'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_25'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_34'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_34'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_35'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_35'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_45'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_45'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_123'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_123'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_123'].extend(dictionary2['trainset_2_3'])

cdictionary2['ctrainset_2_124'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_124'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_124'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_125'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_125'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_125'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_134'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_134'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_134'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_135'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_135'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_135'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_145'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_145'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_145'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_234'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_234'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_234'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_235'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_235'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_235'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_245'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_245'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_245'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_345'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_345'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_345'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_1234'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_1234'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_1234'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_1234'].extend(dictionary2['trainset_2_4'])

cdictionary2['ctrainset_2_1235'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_1235'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_1235'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_1235'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_1245'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_1245'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_1245'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_1245'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_1345'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_1345'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_1345'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_1345'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_2345'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_2345'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_2345'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_2345'].extend(dictionary2['trainset_2_5'])

cdictionary2['ctrainset_2_12345'].extend(dictionary2['trainset_2_1'])
cdictionary2['ctrainset_2_12345'].extend(dictionary2['trainset_2_2'])
cdictionary2['ctrainset_2_12345'].extend(dictionary2['trainset_2_3'])
cdictionary2['ctrainset_2_12345'].extend(dictionary2['trainset_2_4'])
cdictionary2['ctrainset_2_12345'].extend(dictionary2['trainset_2_5'])

# %%
len(cdictionary2)
# Out:
# 26

# %%
#create cdictionary3
cdictionary3['ctrainset_3_12'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_12'].extend(dictionary3['trainset_3_2'])

cdictionary3['ctrainset_3_13'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_13'].extend(dictionary3['trainset_3_3'])

cdictionary3['ctrainset_3_14'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_14'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_15'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_15'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_23'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_23'].extend(dictionary3['trainset_3_3'])

cdictionary3['ctrainset_3_24'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_24'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_25'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_25'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_34'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_34'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_35'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_35'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_45'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_45'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_123'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_123'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_123'].extend(dictionary3['trainset_3_3'])

cdictionary3['ctrainset_3_124'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_124'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_124'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_125'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_125'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_125'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_134'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_134'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_134'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_135'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_135'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_135'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_234'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_234'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_234'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_235'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_235'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_235'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_245'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_245'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_245'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_345'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_345'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_345'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_145'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_145'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_145'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_1234'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_1234'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_1234'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_1234'].extend(dictionary3['trainset_3_4'])

cdictionary3['ctrainset_3_1235'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_1235'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_1235'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_1235'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_1245'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_1245'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_1245'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_1245'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_1345'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_1345'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_1345'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_1345'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_2345'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_2345'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_2345'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_2345'].extend(dictionary3['trainset_3_5'])

cdictionary3['ctrainset_3_12345'].extend(dictionary3['trainset_3_1'])
cdictionary3['ctrainset_3_12345'].extend(dictionary3['trainset_3_2'])
cdictionary3['ctrainset_3_12345'].extend(dictionary3['trainset_3_3'])
cdictionary3['ctrainset_3_12345'].extend(dictionary3['trainset_3_4'])
cdictionary3['ctrainset_3_12345'].extend(dictionary3['trainset_3_5'])

# %%
len(cdictionary3)
# Out:
# 26

# %%
cdictionary4['ctrainset_4_12'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_12'].extend(dictionary4['trainset_4_2'])

cdictionary4['ctrainset_4_13'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_13'].extend(dictionary4['trainset_4_3'])

cdictionary4['ctrainset_4_14'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_14'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_15'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_15'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_23'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_23'].extend(dictionary4['trainset_4_3'])

cdictionary4['ctrainset_4_24'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_24'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_25'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_25'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_34'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_34'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_35'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_35'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_45'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_45'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_123'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_123'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_123'].extend(dictionary4['trainset_4_3'])

cdictionary4['ctrainset_4_124'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_124'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_124'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_125'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_125'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_125'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_134'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_134'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_134'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_135'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_135'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_135'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_234'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_234'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_234'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_235'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_235'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_235'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_245'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_245'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_245'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_345'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_345'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_345'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_145'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_145'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_145'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_1234'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_1234'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_1234'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_1234'].extend(dictionary4['trainset_4_4'])

cdictionary4['ctrainset_4_1235'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_1235'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_1235'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_1235'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_1245'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_1245'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_1245'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_1245'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_1345'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_1345'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_1345'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_1345'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_2345'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_2345'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_2345'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_2345'].extend(dictionary4['trainset_4_5'])

cdictionary4['ctrainset_4_12345'].extend(dictionary4['trainset_4_1'])
cdictionary4['ctrainset_4_12345'].extend(dictionary4['trainset_4_2'])
cdictionary4['ctrainset_4_12345'].extend(dictionary4['trainset_4_3'])
cdictionary4['ctrainset_4_12345'].extend(dictionary4['trainset_4_4'])
cdictionary4['ctrainset_4_12345'].extend(dictionary4['trainset_4_5'])

# %%
len(cdictionary4)
# Out:
# 26

# %%
cdictionary5['ctrainset_5_12'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_12'].extend(dictionary5['trainset_5_2'])

cdictionary5['ctrainset_5_13'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_13'].extend(dictionary5['trainset_5_3'])

cdictionary5['ctrainset_5_14'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_14'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_15'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_15'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_23'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_23'].extend(dictionary5['trainset_5_3'])

cdictionary5['ctrainset_5_24'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_24'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_25'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_25'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_34'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_34'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_35'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_35'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_45'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_45'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_123'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_123'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_123'].extend(dictionary5['trainset_5_3'])

cdictionary5['ctrainset_5_124'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_124'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_124'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_125'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_125'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_125'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_134'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_134'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_134'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_135'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_135'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_135'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_234'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_234'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_234'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_235'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_235'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_235'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_245'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_245'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_245'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_345'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_345'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_345'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_145'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_145'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_145'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_1234'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_1234'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_1234'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_1234'].extend(dictionary5['trainset_5_4'])

cdictionary5['ctrainset_5_1235'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_1235'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_1235'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_1235'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_1245'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_1245'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_1245'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_1245'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_1345'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_1345'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_1345'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_1345'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_2345'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_2345'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_2345'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_2345'].extend(dictionary5['trainset_5_5'])

cdictionary5['ctrainset_5_12345'].extend(dictionary5['trainset_5_1'])
cdictionary5['ctrainset_5_12345'].extend(dictionary5['trainset_5_2'])
cdictionary5['ctrainset_5_12345'].extend(dictionary5['trainset_5_3'])
cdictionary5['ctrainset_5_12345'].extend(dictionary5['trainset_5_4'])
cdictionary5['ctrainset_5_12345'].extend(dictionary5['trainset_5_5'])

# %%
len(cdictionary5)
# Out:
# 26

# %%
cdictionary1File = open(base_dir+"cdictionary1.out", "wb")
pickle.dump(cdictionary1, cdictionary1File)
cdictionary1File.close()

# %%
cdictionary2File = open(base_dir+"cdictionary2.out", "wb")
pickle.dump(cdictionary2, cdictionary2File)
cdictionary2File.close()

# %%
cdictionary3File = open(base_dir+"cdictionary3.out", "wb")
pickle.dump(cdictionary3, cdictionary3File)
cdictionary3File.close()

# %%
cdictionary4File = open(base_dir+"cdictionary4.out", "wb")
pickle.dump(cdictionary4, cdictionary4File)
cdictionary4File.close()

# %%
cdictionary5File = open(base_dir+"cdictionary5.out", "wb")
pickle.dump(cdictionary5, cdictionary5File)
cdictionary5File.close()

# %%
test1 = {}
test2 = {}
testcombine = {}
testcombine['combine'] = []

# %%
test1['1'] = [1]
test2['2'] = [2]
testcombine['combine'].extend(test1['1'])
testcombine['combine'].extend(test2['2'])

print(testcombine)
print(test1)
print(len(testcombine['combine']))
# Out:
# {'combine': [1, 2]}
# {'1': [1]}
# 2
